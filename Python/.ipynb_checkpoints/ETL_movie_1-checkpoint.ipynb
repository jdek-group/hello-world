# %%
# https://www.kaggle.com/datasets/grouplens/movielens-20m-dataset/
# Uncomment the pip install code below if you haven't installed these libraries yet
# !pip install pandas
# !pip install zipfile
# !pip install zipfile2 <-- if unable to find zipfile library (maybe deprecated) , use zipfile2
# !pip install kaggle

# %%
import pandas as pd
import zipfile2
import zipfile
import kaggle

# %%
#chmod 600 '/Users/User/.kaggle/kaggle.json'

# %%
# !kaggle datasets download -d grouplens/movielens-20m-dataset

# %%
# extracting the file from the downloaded zip file
zipfile_name = 'movielens-20m-dataset.zip'
with zipfile.ZipFile(zipfile_name, 'r') as file:
    file.extractall()

# %% [markdown]
# ## Run the cell from below downwards, if above already initiated

# %%
import pandas as pd

# %%
df = pd.read_csv("movie.csv")
df_df = pd.DataFrame(df)
print(df_df)
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 27273   131254        Kein Bund für's Leben (2007)
# 27274   131256       Feuer, Eis & Dosenbier (2002)
# 27275   131258                  The Pirates (2014)
# 27276   131260                 Rentun Ruusu (2001)
# 27277   131262                    Innocence (2014)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...

# %%
# read in the csv file as a pandas dataframe
# checking each tables datatype to make sure of dtype integrity before and after joining
movie = pd.read_csv("movie.csv")
print(movie.info())
print(movie.head())
print(movie.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27278 entries, 0 to 27277
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  27278 non-null  int64
#  1   title    27278 non-null  object
#  2   genres   27278 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 639.5+ KB
# None
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# (27278, 3)

# %%
movie.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
movie.dtypes
# Out:
# movieId     int64
# title      object
# genres     object
# dtype: object

# %%
rating = pd.read_csv("rating.csv")
print(rating.head())
print(rating.shape)
# Out:
#    userId  movieId  rating            timestamp
# 0       1        2     3.5  2005-04-02 23:53:47
# 1       1       29     3.5  2005-04-02 23:31:16
# 2       1       32     3.5  2005-04-02 23:33:39
# 3       1       47     3.5  2005-04-02 23:32:07
# 4       1       50     3.5  2005-04-02 23:29:40
# (20000263, 4)

# %%
rating.head()
# Out:
#    userId  movieId  rating            timestamp
# 0       1        2     3.5  2005-04-02 23:53:47
# 1       1       29     3.5  2005-04-02 23:31:16
# 2       1       32     3.5  2005-04-02 23:33:39
# 3       1       47     3.5  2005-04-02 23:32:07
# 4       1       50     3.5  2005-04-02 23:29:40

# %%
rating.dtypes
# Out:
# userId         int64
# movieId        int64
# rating       float64
# timestamp     object
# dtype: object

# %%
# checking rating unique movieId, can have many users rating the same movie
# the table may come with many userID that might rate movieId that doesn't exist in table above (assumption)
# the movieId is correct for all tables to be joined, come from reliable source provider (assumption)
num_dist_movie_in_rating_table = rating['movieId'].nunique()
num_dist_movie_in_rating_table
# Out:
# 26744

# %%
tag = pd.read_csv("tag.csv")
print(tag.head())
print(tag.shape)
# Out:
#    userId  movieId            tag            timestamp
# 0      18     4141    Mark Waters  2009-04-24 18:19:40
# 1      65      208      dark hero  2013-05-10 01:41:18
# 2      65      353      dark hero  2013-05-10 01:41:19
# 3      65      521  noir thriller  2013-05-10 01:39:43
# 4      65      592      dark hero  2013-05-10 01:41:18
# (465564, 4)

# %%
tag.head()
# Out:
#    userId  movieId            tag            timestamp
# 0      18     4141    Mark Waters  2009-04-24 18:19:40
# 1      65      208      dark hero  2013-05-10 01:41:18
# 2      65      353      dark hero  2013-05-10 01:41:19
# 3      65      521  noir thriller  2013-05-10 01:39:43
# 4      65      592      dark hero  2013-05-10 01:41:18

# %%
tag.dtypes
# Out:
# userId        int64
# movieId       int64
# tag          object
# timestamp    object
# dtype: object

# %%
link = pd.read_csv("link.csv")
print(link.head())
print(link.shape)
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0
# (27278, 3)

# %%
link.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
link.dtypes
# Out:
# movieId      int64
# imdbId       int64
# tmdbId     float64
# dtype: object

# %%
genome_tags = pd.read_csv("genome_tags.csv")
print(genome_tags.head())
print(genome_tags.shape)
# Out:
#    tagId           tag
# 0      1           007
# 1      2  007 (series)
# 2      3  18th century
# 3      4         1920s
# 4      5         1930s
# (1128, 2)

# %%
genome_tags.head()
# Out:
#    tagId           tag
# 0      1           007
# 1      2  007 (series)
# 2      3  18th century
# 3      4         1920s
# 4      5         1930s

# %%
genome_tags.dtypes
# Out:
# tagId     int64
# tag      object
# dtype: object

# %%
genome_scores = pd.read_csv("genome_scores.csv")
print(genome_scores)
print(genome_scores.shape)
# Out:
#           movieId  tagId  relevance
# 0               1      1    0.02500
# 1               1      2    0.02500
# 2               1      3    0.05775
# 3               1      4    0.09675
# 4               1      5    0.14675
# ...           ...    ...        ...
# 11709763   131170   1124    0.58775
# 11709764   131170   1125    0.01075
# 11709765   131170   1126    0.01575
# 11709766   131170   1127    0.11450
# 11709767   131170   1128    0.02175
#
# [11709768 rows x 3 columns]
# (11709768, 3)

# %%
genome_scores.head()
# Out:
#    movieId  tagId  relevance
# 0        1      1    0.02500
# 1        1      2    0.02500
# 2        1      3    0.05775
# 3        1      4    0.09675
# 4        1      5    0.14675

# %%
genome_scores.dtypes
# Out:
# movieId        int64
# tagId          int64
# relevance    float64
# dtype: object

# %%
# WRONG JOIN . REFER BELOW FOR THE CORRECT JOIN
movie_and_rating_left_join = pd.merge(movie, rating, on='movieId', how='left')
# pd.set_option('display.max_rows', None)
movie_and_rating_left_join
# Out:
#           movieId                          title  \
# 0               1               Toy Story (1995)
# 1               1               Toy Story (1995)
# 2               1               Toy Story (1995)
# 3               1               Toy Story (1995)
# 4               1               Toy Story (1995)
# ...           ...                            ...
# 20000792   131254   Kein Bund für's Leben (2007)
# 20000793   131256  Feuer, Eis & Dosenbier (2002)
# 20000794   131258             The Pirates (2014)
# 20000795   131260            Rentun Ruusu (2001)
# 20000796   131262               Innocence (2014)
#
#                                                genres    userId  rating  \
# 0         Adventure|Animation|Children|Comedy|Fantasy       3.0     4.0
# 1         Adventure|Animation|Children|Comedy|Fantasy       6.0     5.0
# 2         Adventure|Animation|Children|Comedy|Fantasy       8.0     4.0
# 3         Adventure|Animation|Children|Comedy|Fantasy      10.0     4.0
# ...

# %%
movie_and_rating_left_join.dtypes
# Out:
# movieId        int64
# title         object
# genres        object
# userId       float64
# rating       float64
# timestamp     object
# dtype: object

# %%
movie_and_rating_right_join = pd.merge(movie, rating, on='movieId', how='right')
movie_and_rating_right_join
# Out:
#           movieId                                              title  \
# 0               2                                     Jumanji (1995)
# 1              29  City of Lost Children, The (Cité des enfants p...
# 2              32          Twelve Monkeys (a.k.a. 12 Monkeys) (1995)
# 3              47                        Seven (a.k.a. Se7en) (1995)
# 4              50                         Usual Suspects, The (1995)
# ...           ...                                                ...
# 20000258    68954                                          Up (2009)
# 20000259    69526         Transformers: Revenge of the Fallen (2009)
# 20000260    69644              Ice Age: Dawn of the Dinosaurs (2009)
# 20000261    70286                                  District 9 (2009)
# 20000262    71619      Coco Before Chanel (Coco avant Chanel) (2009)
#
#                                                      genres  userId  rating  \
# ...

# %%
movie_and_rating_right_join.dtypes
# Out:
# movieId        int64
# title         object
# genres        object
# userId         int64
# rating       float64
# timestamp     object
# dtype: object

# %%
# checking for missing values 
has_missing_values = movie_and_rating_right_join['userId'].isnull().sum()
has_missing_values
# Out:
# 0

# %%
# Exploration
# check how many distinct users in userId
num_distinct_users = movie_and_rating_right_join['userId'].nunique()
print(f'Number of distinct users: {num_distinct_users}')
# Out:
# Number of distinct users: 138493

# %%
# # selecting first 10,000 unique 'userId' values to reduce downtime for computation
# # step 1: extract unique userId values and sort them
# unique_user_ids = sorted(movie_and_rating_right_join['userId'].dropna().unique())

# # step 2: select first 10,000 users
# selected_users = unique_user_ids[:100000]

# # step 3: convert to dataframe for easy viewing?
# sample_10000_df = movie_and_rating_right_join[selected_users]
# sample_10000_df

# %%
# Step 1: Extract unique userId values and sort them
unique_user_ids = movie_and_rating_right_join['userId'].dropna().unique()

# Step 2: Select the first 10,000 users
# selected_users = unique_user_ids[:10000] #out of memory 150k+ rows
# selected_users = unique_user_ids[:500]   #out of memory (71554, 6)
selected_users = unique_user_ids[:100]     #(11101, 6)

# Step 3: Filter the DataFrame to include only rows with the selected userIds
sample_10000_df = movie_and_rating_right_join[movie_and_rating_right_join['userId'].isin(selected_users)]

# View the resulting DataFrame
# sample_10000_df.head(1000)
sample_10000_df
# Out:
#        movieId                                              title  \
# 0            2                                     Jumanji (1995)
# 1           29  City of Lost Children, The (Cité des enfants p...
# 2           32          Twelve Monkeys (a.k.a. 12 Monkeys) (1995)
# 3           47                        Seven (a.k.a. Se7en) (1995)
# 4           50                         Usual Suspects, The (1995)
# ...        ...                                                ...
# 11096      780               Independence Day (a.k.a. ID4) (1996)
# 11097     1112                                Palookaville (1996)
# 11098     1210  Star Wars: Episode VI - Return of the Jedi (1983)
# 11099     1449                         Waiting for Guffman (1996)
# 11100     1527                          Fifth Element, The (1997)
#
#                                        genres  userId  rating  \
# 0                  Adventure|Children|Fantasy       1     3.5
# ...

# %%
# checking for userId 1, how many movies they have seen? 
userId_1_only = movie_and_rating_right_join[movie_and_rating_right_join['userId'] == 1]
pd.set_option('display.max_rows', None)
userId_1_only
# Out:
#      movieId                                              title  \
# 0          2                                     Jumanji (1995)
# 1         29  City of Lost Children, The (Cité des enfants p...
# 2         32          Twelve Monkeys (a.k.a. 12 Monkeys) (1995)
# 3         47                        Seven (a.k.a. Se7en) (1995)
# 4         50                         Usual Suspects, The (1995)
# 5        112         Rumble in the Bronx (Hont faan kui) (1995)
# 6        151                                     Rob Roy (1995)
# 7        223                                      Clerks (1994)
# 8        253  Interview with the Vampire: The Vampire Chroni...
# 9        260          Star Wars: Episode IV - A New Hope (1977)
# 10       293  Léon: The Professional (a.k.a. The Professiona...
# 11       296                                Pulp Fiction (1994)
# 12       318                   Shawshank Redemption, The (1994)
# 13       337                 What's Eating Gilbert Grape (1993)
# ...

# %%
# reset back max_rows display to default value so your display window won't crash for rows > your laptop could handle (out of memory)
pd.reset_option('display.max_rows')

# %%
userId_1_only
# Out:
#      movieId                                              title  \
# 0          2                                     Jumanji (1995)
# 1         29  City of Lost Children, The (Cité des enfants p...
# 2         32          Twelve Monkeys (a.k.a. 12 Monkeys) (1995)
# 3         47                        Seven (a.k.a. Se7en) (1995)
# 4         50                         Usual Suspects, The (1995)
# ..       ...                                                ...
# 170     8507                                      Freaks (1932)
# 171     8636                                Spider-Man 2 (2004)
# 172     8690                         Slaughterhouse-Five (1972)
# 173     8961                            Incredibles, The (2004)
# 174    31696                                 Constantine (2005)
#
#                                          genres  userId  rating  \
# 0                    Adventure|Children|Fantasy       1     3.5
# 1        Adventure|Drama|Fantasy|Mystery|Sci-Fi       1     3.5
# ...
